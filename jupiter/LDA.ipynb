# %%
import pandas as pd

# %%
columns=['comments','date','color','size','plus','minuse','rate','name','brand']

# %%
df=pd.read_json('/home/sv/Dev/Dev_bootcamp/Wildberries_bot/5044562.jl')

# %%
df=df.transpose().reset_index().drop('index', axis=1)

# %%
df=df.rename(columns={0:'comments',1:'date',2:'color',3:'size',4:'plus',5:'minuse',6:'rate',7:'name',8:'brand'})

# %%
df
# Out:
#                                                comments  \
# 0     Отличный пылесос, свою функцию выполняет , пыл...
# 1     Всасывает хорошо. Шнура достаточно. На фильтр ...
# 2     Для этой цены, пылесос отличный. Очень лёгкий ...
# 3     Пылесос очень-очень хороший! Любимец мой! Втор...
# 4                              Отличный за эту цену!!!!
# ...                                                 ...
# 3431                Отличный пылесос, легко собирается.
# 3432                              ОЧЕНЬ УДОБНО И ХОРОШО
# 3433  Удобный, лёгкий малыш. Тянен хорошо. За такие ...
# 3434           спасибо все отлично работает     советую
# 3435  Приобрела за 1372. Отличный помощник за эти де...
#
#                                 date           color size plus minuse rate  \
# 0               2021-05-02T15:45:07Z                    0    1      0    5
# 1               2021-05-02T13:47:36Z                    0    1      0    5
# 2               2021-05-02T11:38:03Z                    0    2      0    5
# 3               2021-05-02T06:17:10Z                    0    2      0    5
# 4               2021-05-01T16:51:28Z                    0    1      0    5
# ...                              ...             ...  ...  ...    ...  ...
# 3431  2019-09-26T08:01:16.536772217Z  голубой, белый    0    3      5    5
# 3432  2019-11-20T12:46:21.171350589Z  голубой, белый    0    1      1    5
# 3433  2019-11-20T08:35:32.786532909Z  голубой, белый    0    1      1    5
# 3434  2019-11-20T06:29:51.268463604Z  голубой, белый    0    0      1    5
# 3435  2019-11-20T04:47:40.860265718Z  голубой, белый    0    1      1    5
#
#                 name   brand
# 0     Пылесос GL6256  GALAXY
# 1     Пылесос GL6256  GALAXY
# 2     Пылесос GL6256  GALAXY
# 3     Пылесос GL6256  GALAXY
# 4     Пылесос GL6256  GALAXY
# ...              ...     ...
# 3431  Пылесос GL6256  GALAXY
# 3432  Пылесос GL6256  GALAXY
# 3433  Пылесос GL6256  GALAXY
# 3434  Пылесос GL6256  GALAXY
# 3435  Пылесос GL6256  GALAXY
#
# [3436 rows x 9 columns]

# %% [markdown]
# создать отдельный файл и назвать preprocessing_tools

# %%
import re

import nltk
from nltk.corpus import stopwords

def delete_non_letters(words):
    new_words = []
    for word in words:
        new_word = "".join(c for c in word if c.isalpha())
        if new_word != '':
            new_words.append(new_word)
    return new_words

def delete_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopwords.words('english') and word not in stopwords.words('russian'):
            new_words.append(word)
    return new_words

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def normalize(text, tokenized=False, del_stopwords=False):
    if not tokenized:
        text = nltk.word_tokenize(text)
    
    text = delete_non_letters(text)
    if del_stopwords:
        text = delete_stopwords(text)
        
    text = to_lowercase(text)
    
    text = [word for word in text if len(word) > 1]
    return text

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import cm as cm
import numpy as np
from numpy.random import choice

import nltk
from nltk.corpus import stopwords as nltk_stopwords

from sklearn.model_selection import train_test_split

from os.path import join
from glob import glob

#import preprocessing_tools as pt
from tqdm import tqdm_notebook as tqdm

import pickle

from os import mkdir 
from shutil import move

# %%
 #loading data
#data_path = '../Data/raw_data'

#template = join(data_path,'*.txt')
#filenames = glob(template)
#print(len(filenames))

# %%
 #Let`\s tokenize all texts and collect texts lenghts to see texts lengths distribution.
import nltk
nltk.download('punkt')
texts_lens = []
tok_text_arr=[]
for name in df['comments']:
   # with open(name, 'r') as f:
        text = name
        tok_text = nltk.word_tokenize(text)
        tok_text = normalize(tok_text, tokenized=True)
        tok_text_arr.append(tok_text)
        texts_lens.append(len(tok_text))

df['tok_comments']= [','.join(i) for i in tok_text_arr ]
df
# Out:
# [nltk_data] Downloading package punkt to /home/sv/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                comments  \
# 0                              Отличный за эту цену!!!!
# 1     Все отлично. Всасывает даже комточки от финико...
# 2     Пылесос отличный, работает супер, мощный. Очис...
# 3     Хороший пылесос. Компактный. Дома линолеум и п...
# 4     Плохо выполняет свои функции, ужасно. Плохой п...
# ...                                                 ...
# 3427           спасибо все отлично работает     советую
# 3428  Приобрела за 1372. Отличный помощник за эти де...
# 3429  пылесос проверили в пункте выдачи, заполнили в...
# 3430  Офигенный пылесос. Купила почти за 1000 руб. к...
# 3431  Отличный пылесос за эти деньги, хорошо сосёт, ...
#
#                                 date           color size plus minuse rate  \
# 0               2021-05-01T16:51:28Z                    0    1      0    5
# 1               2021-05-01T15:04:18Z                    0    1      0    5
# 2               2021-05-01T11:12:07Z                    0    1      0    5
# 3               2021-05-01T07:32:57Z                    0    1      0    5
# 4               2021-05-01T06:50:42Z                    0    0      1    1
# ...                              ...             ...  ...  ...    ...  ...
# 3427  2019-11-20T06:29:51.268463604Z  голубой, белый    0    0      1    5
# 3428  2019-11-20T04:47:40.860265718Z  голубой, белый    0    1      1    5
# 3429  2019-11-19T13:36:30.630725501Z  голубой, белый    0    2      1    5
# 3430  2019-11-19T12:54:38.765041548Z  голубой, белый    0    3      2    5
# 3431  2019-11-19T07:48:26.753753662Z  голубой, белый    0    3      2    5
#
#                 name   brand  \
# 0     Пылесос GL6256  GALAXY
# 1     Пылесос GL6256  GALAXY
# 2     Пылесос GL6256  GALAXY
# 3     Пылесос GL6256  GALAXY
# 4     Пылесос GL6256  GALAXY
# ...              ...     ...
# 3427  Пылесос GL6256  GALAXY
# 3428  Пылесос GL6256  GALAXY
# 3429  Пылесос GL6256  GALAXY
# 3430  Пылесос GL6256  GALAXY
# 3431  Пылесос GL6256  GALAXY
#
#                                            tok_comments
# 0                                  отличный,за,эту,цену
# 1     все,отлично,всасывает,даже,комточки,от,фиников...
# 2     пылесос,отличный,работает,супер,мощный,очистил...
# 3     хороший,пылесос,компактный,дома,линолеум,плитк...
# 4     плохо,выполняет,свои,функции,ужасно,плохой,пла...
# ...                                                 ...
# 3427               спасибо,все,отлично,работает,советую
# 3428  приобрела,за,отличный,помощник,за,эти,деньги,л...
# 3429  пылесос,проверили,пункте,выдачи,заполнили,все,...
# 3430  офигенный,пылесос,купила,почти,за,руб,купила,с...
# 3431  отличный,пылесос,за,эти,деньги,хорошо,сосёт,но...
#
# [3432 rows x 10 columns]

# %%
plt.hist(texts_lens, bins=[i * 100 for i in range(int(1000/100))])
plt.show()

# %%
max(texts_lens)
# Out:
# 147

# %%
df.loc[0,'name'].split()[0]
# Out:
# 'Пылесос'

# %%
#loading stopwords from all the sources we got

#loading text files with external stopwords
#merging via set.update()
#stopwords_path = join('../Data/stopwords/raw_stopwords')
#stopwords_template = join(stopwords_path, '*.txt')
#stopwords_files = glob(stopwords_template)
#extra_stopwords = set()
#for name in stopwords_files:
#    with open(name, 'r') as f:
#        words = f.readlines()
#        words = [word.strip() for word in words]
#        extra_stopwords.update(set(words))

#Also putting there nltk stopwords
stopwords = set()
stopwords.update(set(nltk_stopwords.words('english')))
stopwords.update(set(nltk_stopwords.words('russian')))
#stopwords.update(extra_stopwords)

#some euristically added stopwords
custom_stopwords = set(['http', 'https', 'ru', 'com', 'vk',
                         'привет', 'здравствуйте', 'например', 'репост',df.loc[0,'name'].split()[0]])

#stopwords from final LDA tuning
#comment this piece it if you haven`t got them.

#final_stopwords_path = join(stopwords_path, 'final_extra_stopwords.pkl')
#with open(final_stopwords_path, 'rb') as f:
 #   stopwords_from_top = pickle.load(f)
#stopwords.update(set(stopwords_from_top))

stopwords.update(custom_stopwords)
stopwords = list(stopwords)
print('Total numver of stopwords:', len(stopwords))

#serializing all-merged stopwords set
#with open('../Data/stopwords/stopwords.pkl', 'wb') as f:
 #   pickle.dump(stopwords, f)
# Out:
# Total numver of stopwords: 340

# %%
stopwords
# Out:
# ['он',
#  'under',
#  'есть',
#  'both',
#  'что',
#  'the',
#  'какой',
#  'wasn',
#  'чтоб',
#  'not',
#  'herself',
#  'мы',
#  'тебя',
#  'репост',
#  'чтобы',
#  'does',
#  'by',
#  'any',
#  "that'll",
#  "it's",
#  'так',
#  'm',
#  'or',
#  'up',
#  'куда',
#  'ни',
#  'doesn',
#  'he',
#  'я',
#  'себя',
#  'в',
#  'иногда',
#  'then',
#  'll',
#  'just',
#  'же',
#  'ты',
#  'our',
#  'and',
#  'всю',
#  'здравствуйте',
#  'лучше',
#  'same',
#  'during',
#  'было',
#  'about',
#  'опять',
#  'над',
#  'ним',
#  'what',
#  'него',
#  'был',
#  'if',
#  'some',
#  'надо',
#  'потом',
#  'когда',
#  'вот',
#  'чем',
#  "you're",
#  'that',
#  'd',
#  'other',
#  'a',
#  'где',
#  'below',
#  'in',
#  "won't",
#  "wouldn't",
#  'чего',
#  'об',
#  'himself',
#  'most',
#  'во',
#  'более',
#  'nor',
#  'before',
#  "hadn't",
#  'меня',
#  'там',
#  'были',
#  "aren't",
#  'этой',
#  'very',
#  'вы',
#  "you'd",
#  'to',
#  'isn',
#  'после',
#  'если',
#  'is',
#  'doing',
#  "weren't",
#  'now',
#  "mustn't",
#  'за',
#  'все',
#  'ли',
#  'an',
#  'у',
#  'нельзя',
#  'me',
#  'тут',
#  'weren',
#  'между',
#  'да',
#  'еще',
#  'own',
#  "hasn't",
#  'at',
#  'theirs',
#  'была',
#  'из',
#  'too',
#  'shouldn',
#  'while',
#  'who',
#  'more',
#  'или',
#  'нет',
#  'разве',
#  'про',
#  "don't",
#  "shouldn't",
#  'don',
#  'but',
#  'again',
#  'needn',
#  'можно',
#  'y',
#  'which',
#  'почти',
#  'against',
#  'between',
#  'чуть',
#  "isn't",
#  'эту',
#  'mustn',
#  've',
#  "should've",
#  'они',
#  'him',
#  'зачем',
#  'ее',
#  "she's",
#  'хоть',
#  'здесь',
#  'has',
#  'myself',
#  'его',
#  "couldn't",
#  'did',
#  'hers',
#  'под',
#  'много',
#  'yourself',
#  'том',
#  'например',
#  'от',
#  'should',
#  'having',
#  'наконец',
#  'другой',
#  'совсем',
#  'how',
#  'какая',
#  'off',
#  'until',
#  'один',
#  'перед',
#  'so',
#  'конечно',
#  'будет',
#  'they',
#  "wasn't",
#  'this',
#  'со',
#  'уже',
#  'was',
#  'had',
#  'ru',
#  'даже',
#  'vk',
#  'yours',
#  'нее',
#  'при',
#  'этом',
#  'всегда',
#  'these',
#  'yourselves',
#  'ей',
#  'mightn',
#  'do',
#  'такой',
#  'ну',
#  "didn't",
#  'вам',
#  'whom',
#  'it',
#  'were',
#  'will',
#  'https',
#  'но',
#  'то',
#  'their',
#  'себе',
#  'для',
#  'no',
#  'привет',
#  'when',
#  'we',
#  'с',
#  'won',
#  'Пылесос',
#  'больше',
#  'them',
#  'from',
#  'once',
#  "shan't",
#  'she',
#  'впрочем',
#  'вас',
#  "you've",
#  'ma',
#  'к',
#  'wouldn',
#  'of',
#  'haven',
#  'этого',
#  'o',
#  'ain',
#  'hadn',
#  'как',
#  'о',
#  'вдруг',
#  'those',
#  'потому',
#  'be',
#  'уж',
#  'itself',
#  'shan',
#  'its',
#  'кто',
#  'being',
#  'моя',
#  'она',
#  'свою',
#  'because',
#  'few',
#  "haven't",
#  'have',
#  'ней',
#  'hasn',
#  'тоже',
#  'не',
#  'further',
#  'been',
#  'such',
#  'here',
#  'сам',
#  'до',
#  'ours',
#  'all',
#  'didn',
#  'нас',
#  'хорошо',
#  'ourselves',
#  'мой',
#  'ведь',
#  'above',
#  "needn't",
#  'are',
#  'будто',
#  'for',
#  "mightn't",
#  'themselves',
#  're',
#  'ничего',
#  'after',
#  'через',
#  'того',
#  'три',
#  'out',
#  'as',
#  'без',
#  'нибудь',
#  'there',
#  'you',
#  's',
#  'ему',
#  'http',
#  'эти',
#  'бы',
#  'with',
#  'i',
#  'может',
#  'am',
#  'com',
#  'раз',
#  'her',
#  'сейчас',
#  "doesn't",
#  'down',
#  'мне',
#  'each',
#  'их',
#  'и',
#  'on',
#  'than',
#  'всех',
#  'только',
#  'тот',
#  'over',
#  'my',
#  'тем',
#  'why',
#  'тогда',
#  'your',
#  'only',
#  't',
#  'них',
#  'aren',
#  'по',
#  'теперь',
#  'through',
#  'where',
#  'два',
#  'никогда',
#  'ж',
#  "you'll",
#  'а',
#  'his',
#  'can',
#  'им',
#  'на',
#  'couldn',
#  'всего',
#  'быть',
#  'into',
#  'этот']

# %% [markdown]
#  # Idf filtering

# %%
# !pip install pymystem3
# Out:
# Requirement already satisfied: pymystem3 in /home/sv/anaconda3/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: requests in /home/sv/anaconda3/lib/python3.8/site-packages (from pymystem3) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/sv/anaconda3/lib/python3.8/site-packages (from requests->pymystem3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sv/anaconda3/lib/python3.8/site-packages (from requests->pymystem3) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sv/anaconda3/lib/python3.8/site-packages (from requests->pymystem3) (1.26.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/sv/anaconda3/lib/python3.8/site-packages (from requests->pymystem3) (4.0.0)

# %%
# %matplotlib inline
#adding this to avoid memory errors
#%env JOBLIB_TEMP_FOLDER=/tmp
import numpy as np

from tqdm import tqdm_notebook as tqdm

#from sklearn.externals import joblib
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.model_selection import train_test_split
import pickle

import nltk
from nltk.corpus import stopwords
from pymystem3 import Mystem
import re

from os.path import join
from glob import glob

from time import time

# %%
#'training' (tf-)idf vectorizer.
tf_idf = TfidfVectorizer()

# %%
df['tok_comments'].to_numpy()
# Out:
# array(['отличный,за,эту,цену',
#        'все,отлично,всасывает,даже,комточки,от,фиников,маслин,ним,легко,пылесосить',
#        'пылесос,отличный,работает,супер,мощный,очистил,коврик,прихожей,ванной,теперь,как,новые,но,пришел,разорванной,коробке,все,детали,на,месте',
#        ...,
#        'пылесос,проверили,пункте,выдачи,заполнили,все,документы,проверила,дома,пока,все,на,отлично,шерсть,от,двух,собак,собирает,очень,хорошо,по,ламинату,ковров,меня,нет,так,что,не,могу,ничего,сказатьшнур,немного,коротковат,на,всю,квартиру,не,хватает,но,удлинитель,помощь',
#        'офигенный,пылесос,купила,почти,за,руб,купила,себе,мамам,отлично,справляется,ламинатом,ковром,плиткой,собирает,всю,шерсть,короче,восторге',
#        'отличный,пылесос,за,эти,деньги,хорошо,сосёт,но,шумный,как,писали,все,до,меня,так,рекомендую'],
#       dtype=object)

# %%
tf_idf.fit(df['tok_comments'].to_numpy())
# Out:
# TfidfVectorizer()

# %%
#getting idfs
idfs = tf_idf.idf_
idfs
# Out:
# array([8.44804261, 8.44804261, 8.44804261, ..., 8.44804261, 8.44804261,
#        8.44804261])

# %%
#sorting out too rare and too common words
#original 1.3 and 7
# 2 6
lower_thresh = 3.
upper_thresh = 6.
not_often = idfs > lower_thresh
not_rare = idfs < upper_thresh

mask = not_often * not_rare

good_words = np.array(tf_idf.get_feature_names())[mask]
#deleting punctuation as well.
cleaned = []
for word in good_words:
    word = re.sub("^(\d+\w*$|_+)", "", word)
    
    if len(word) == 0:
        continue
    cleaned.append(word)
print("Len of original vocabulary: %d\nAfter filtering: %d"%(idfs.shape[0], len(cleaned)))
# Out:
# Len of original vocabulary: 9215
# After filtering: 499

# %% [markdown]
# # Stemming

# %%
#Stemming
m = Mystem()
stemmed = set()
voc_len = len(cleaned)
for i in tqdm(range(voc_len)):
    word = cleaned.pop()
    stemmed_word = m.lemmatize(word)[0]
    stemmed.add(stemmed_word)
    
stemmed = list(stemmed)
print('After stemming: %d'%(len(stemmed)))
# Out:
# <ipython-input-439-3c28adbad111>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(voc_len)):
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=499.0), HTML(value='')))
# After stemming: 347

# %% [markdown]
# # Term-doc matrix

# %%
#training count vectorizer
voc = {word : i for i,word in enumerate(stemmed)}

count_vect = CountVectorizer(
                             
                             vocabulary=voc)

dataset = count_vect.fit_transform(df['tok_comments'].to_numpy())

# %% [markdown]
# #  LDA

# %%
#training LDA
lda = LDA(n_components = 60, max_iter=30, n_jobs=6, learning_method='batch', verbose=1)
lda.fit(dataset)
# Out:
# iteration: 1 of max_iter: 30
# iteration: 2 of max_iter: 30
# iteration: 3 of max_iter: 30
# iteration: 4 of max_iter: 30
# iteration: 5 of max_iter: 30
# iteration: 6 of max_iter: 30
# iteration: 7 of max_iter: 30
# iteration: 8 of max_iter: 30
# iteration: 9 of max_iter: 30
# iteration: 10 of max_iter: 30
# iteration: 11 of max_iter: 30
# iteration: 12 of max_iter: 30
# iteration: 13 of max_iter: 30
# iteration: 14 of max_iter: 30
# iteration: 15 of max_iter: 30
# iteration: 16 of max_iter: 30
# iteration: 17 of max_iter: 30
# iteration: 18 of max_iter: 30
# iteration: 19 of max_iter: 30
# iteration: 20 of max_iter: 30
# iteration: 21 of max_iter: 30
# iteration: 22 of max_iter: 30
# iteration: 23 of max_iter: 30
# iteration: 24 of max_iter: 30
# iteration: 25 of max_iter: 30
# iteration: 26 of max_iter: 30
# iteration: 27 of max_iter: 30
# iteration: 28 of max_iter: 30
# iteration: 29 of max_iter: 30
# iteration: 30 of max_iter: 30
# LatentDirichletAllocation(max_iter=30, n_components=60, n_jobs=6, verbose=1)

# %%
LDA(batch_size=128, doc_topic_prior=None,
             evaluate_every=-1, learning_decay=0.7,
             learning_method='batch', learning_offset=10.0,
             max_doc_update_iter=100, max_iter=30, mean_change_tol=0.001,
             n_components=60, n_jobs=6,  perp_tol=0.1,
             random_state=None, topic_word_prior=None,
             total_samples=1000000.0, verbose=1)
# Out:
# LatentDirichletAllocation(max_iter=30, n_components=60, n_jobs=6, verbose=1)

# %%
#Let\`s do simple interface class
class TopicModeler(object):
    '''
    Inteface object for CountVectorizer + LDA simple
    usage.
    '''
    def __init__(self, count_vect, lda):
        '''
        Args:
             count_vect - CountVectorizer object from sklearn.
             lda - LDA object from sklearn.
        '''
        self.lda = lda
        self.count_vect = count_vect
        self.count_vect.input = 'content'
        
    def __call__(self, text):
        '''
        Gives topics distribution for a given text
        Args:
             text - raw text via python string.
        returns: numpy array - topics distribution for a given text.
        '''
        vectorized = self.count_vect.transform([text])
        lda_topics = self.lda.transform(vectorized)
        return lda_topics
    def get_keywords(self, text, n_topics=3, n_keywords=5):
        '''
        For a given text gives n top keywords for each of m top texts topics.
        Args:
             text - raw text via python string.
             n_topics - int how many top topics to use.
             n_keywords - how many top words of each topic to return.
        returns:
                list - of m*n keywords for a given text.
        '''
        lda_topics = self(text)
        lda_topics = np.squeeze(lda_topics, axis=0)
        n_topics_indices = lda_topics.argsort()[-n_topics:][::-1]
        
        top_topics_words_dists = []
        for i in n_topics_indices:
            top_topics_words_dists.append(self.lda.components_[i])
        
        keywords = np.zeros(shape=(n_keywords*n_topics, self.lda.components_.shape[1]))
        for i,topic in enumerate(top_topics_words_dists):
            n_keywords_indices = topic.argsort()[-n_keywords:][::-1]
            for k,j in enumerate(n_keywords_indices):
                keywords[i * n_keywords + k, j] = 1
        keywords = self.count_vect.inverse_transform(keywords)
        keywords = [keyword[0] for keyword in keywords]
        return keywords

# %%
text=''.join(df['tok_comments'].to_numpy())
text
# Out:
# 'отличный,за,эту,ценувсе,отлично,всасывает,даже,комточки,от,фиников,маслин,ним,легко,пылесоситьпылесос,отличный,работает,супер,мощный,очистил,коврик,прихожей,ванной,теперь,как,новые,но,пришел,разорванной,коробке,все,детали,на,местехороший,пылесос,компактный,дома,линолеум,плитка,со,своей,функцией,справляется,отлично,рекомендуюплохо,выполняет,свои,функции,ужасно,плохой,пластик,плохая,система,разберитесь,этимпылесос,хороший,собирает,пыль,кошачьи,волосы,хорошо,покупкой,довольнаоднозначно,супер,пылесос,после,пользования,приобрела,для,дочерипылесос,просто,огонь,заказала,ещё,доченьке,рекомендую,спасибо,валбериссупер,мощный,маленький,пылесосхороший,для,своей,ценызаказала,пылесос,забрала,апреля,коробка,разорвана,облекаяна,скотчем,сзади,может,вывалиться,ну,это,ладно,нету,ручки,что,мне,делать,этим,полупылесосом,очень,разочарована,вернуть,нельзя,так,понимаюне,нарадуюсь,работает,четвертый,месяц,без,проблем,за,такую,цену,просто,чудесная,штукаэлектро,веник,супержаль,что,на,коробке,нет,защитных,пломб,открыл,бери,что,хочешь,мне,пришёл,полный,комплект,всё,отлично,работает,довольна,покупкойочень,понравился,помощниклегкий,тянет,на,стены,потолок,им,удобно,почистиь,но,пол,ковром,довольна,на,каждый,день,простоочень,понравился,компактный,удобныйэто,какой,то,кошмар,товар,пришел,без,напольной,щетки,хотя,коробка,была,заклеена,скотчем,поэтому,не,вызвало,подозрений,возврате,отказали,теперь,что,делать,этим,полупылесосом,не,знаю,хотя,бы,счетка,такая,отдельно,продавалась,товар,вернула,через,мин,для,чего,пишут,гарантия,года,присваивают,випклиентнормальный,мощность,хорошая,но,так,как,нет,щетки,паласы,не,берет,для,легкой,уборкиотличный,пылесос,убирает,квартиру,квм,без,всяких,сложностей,лёгкий,удобный,пользуемся,год,сломалась,вверху,пластиковая,ручка,начало,отпадывать,колёсико,но,это,уборке,не,мешаеткоробка,компактная,все,пришло,целостности,нетяжелый,шум,пределах,нормы,как,мне,показалось,но,мы,не,ожидали,такой,результат,виду,ковер,казался,чистый,он,собрал,столько,волос,крутой,мы,довольнысвою,цену,оправдывает,читала,отрицательные,отзывы,сомневалась,но,все,пришло,целости,сохранности,шнур,довольно,длинный,комната,метров,хватает,от,одного,края,до,другого,покупала,для,авто,но,пользуемся,дома,кухня,одна,из,комнат,пользуемся,октября,при,использовании,не,воняет,как,некоторых,естественно,нельзя,рассчитывать,на,большой,объем,площади,он,не,для,этогопылесос,очень,понравился,маленький,маневренный,для,ежедневной,уборки,самое,то,на,фильтр,сразу,одела,капроновый,насок,очень,удобно,фильтр,не,так,забивается,пылью,убирать,ним,удно,удовольствие,даже,дети,справляются,шумит,как,обычный,пылесос,немного,греется,корпус,где,мотор,но,это,всех,пылесос,так,общем,отличный,помощник,для,тех,где,есть,дети,животные,да,для,людей,старшей,возрастной,категории,отличный,помощниквозврат,пришел,не,комплект,не,было,ручки,попробовать,быту,не,удалосьэто,просто,веник,для,кухни,ткщетки,нет,палас,чистит,плохолучший,счастью,нет,предела,долго,сомневалась,теперь,понимаю,что,зря,упаковка,была,конечно,помята,но,сам,пылесос,мощный,не,забывайте,чулке,еще,хороший,лайфхак,среди,отзывовпокупали,два,года,назад,до,сих,работает,супермощность,хорошая,колесо,отлетело,день,думаю,долго,не,прослужит,очень,хлипкий,на,видпрослужил,месяца,сдох,отключается,постоянно,шнур,отошёл,сразу,буду,оформлять,возвратпонравился,лёгкий,мощныйпользуюсь,почти,год,очень,удобно,когда,надо,быстро,убрать,коридоре,большой,не,хочется,доставать,соотношение,цена,качество,спасибосоответствует,цене,принципе,терпимопылесос,просто,огонь,очень,мощный,на,первый,взгляд,кажется,игрушечным,хлипким,но,как,показала,практика,пылесос,мощный,надежный,единственный,минус,провод,коротковатпылесос,отличный,очень,мощно,собирает,пыль,рекомендуюпросто,отличный,пылесос,заказывала,маме,на,день,рождения,мама,восторге,закажу,себе,такой,жезаказ,пришел,быстро,все,хоршо,спасиборазве,можно,продавать,таком,виде,даже,не,стала,смотреть,коробка,хуже,чем,помойки,рваная,вся,перемотанная,скочем,как,будто,ее,топтали,рвали,пачкали,потом,решили,втюхать,покупателю,неприятно,даже,руки,брать,п ...

# %%
tm = TopicModeler(count_vect, lda)

# %%
 #Let`s what words it will give us for the choosen text.
key_words = tm.get_keywords(text, n_topics=1, n_keywords=20)
print(key_words)
# Out:
# ['он', 'что', 'ну', 'сказать', 'себя', 'так', 'по', 'это', 'да', 'даже', 'может', 'нужно', 'мой', 'плюс', 'длинный', 'много', 'всего', 'сначала', 'этот', 'потому']

# %% [markdown]
# пропустила кусок!!!

# %% [markdown]
# # Making texts embeddings

# %%
term_doc_matrix = count_vect.transform(df['tok_comments'])
embeddings = lda.transform(term_doc_matrix)

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN, AffinityPropagation, SpectralClustering, KMeans

# %%
kmeans = KMeans(n_clusters=3)
clust_labels = kmeans.fit_predict(embeddings)
clust_centers = kmeans.cluster_centers_

# %%
embeddings_to_tsne = np.concatenate((embeddings,clust_centers), axis=0)

tSNE =  TSNE(n_components=2, perplexity=15)
tsne_embeddings = tSNE.fit_transform(embeddings_to_tsne)
tsne_embeddings, centroids_embeddings = np.split(tsne_embeddings, [len(clust_labels)], axis=0)

# %%
print(tsne_embeddings.shape,centroids_embeddings.shape)
# Out:
# (977, 2) (3, 2)

# %%
clust_indices = np.unique(clust_labels)

clusters = {clust_ind : [] for clust_ind in clust_indices}
for emb, label in zip(tsne_embeddings, clust_labels):
    clusters[label].append(emb)

for key in clusters.keys():
    clusters[key] = np.array(clusters[key])
colors = cm.rainbow(np.linspace(0, 1, len(clust_indices)))

# %%
count=0
for i in range(len(clust_labels)):
    if clust_labels[i]==0:
        print(df['comments'][i])
# Out:
# Конверт для выписки вместо худи, серьезно?! Ну какого фига, ВБ?!
# Это просто самое бомбовое худи которое только может быть, цвет соответствует, оно максимально уютное, мягкое, швы все идеальные, нитки нигде не торчат, на мои параметры( ОГ-101; ОТ-90 ; ОБ-114) село как по мне идеально, я в восторге, теперь хочу такое желтое или красное😍
# Спасибо за отличный товар!
# Очень понравилось худи )Все качественно сшито, приятный мягкий материал, тёплое и уютное )Увидела у подруги и решила заказать себе . До первой стирки , не много будут оставаться катышки с внутренней стороны на одежде , но это во всех изделиях такого плана. Стираю при температуре 20-30 градусов на щадящем режиме . Чтоб подклад "не сыпался " нужно после первой стирке хорошо прогладить с внутренней стороны ) Закажу себе в другом цвете )
# худи действительно огромное, но с таким расчётом и брала - носить дома в прохладный сезон. очень уютная вещичка, как кокон. на миниатюрных ледях будет смотреться комично (:
# Худи не плохое, из всех, что заказывала на Wildberries это самое лучшее, по крою и качеству. Ещё не стирала, думаю, что внутренняя мягкая подкладка уйдёт после 2-3 стирок, но это нормально. Не понравилось только то, что я заплатила на 100 рублей дороже, чем оно стоит сейчас😐😐
# Потрясающее худи! Я взяла двух цветов: черное и сиреневое. В них так уютно. Ткань приятная к телу. Крой отличный, сшито качественно.
# Очень классный крой у худи, но я не решилась брать в цвете терракот, потому что заметила пару пятен-разводов, а такие пятна имеют тенденцию становиться больше и портить внешний вид изделия, поэтому пересказала в чёрном. Кстати, никаких катышек в моем случае не было.
# Покупала чёрный, сел на мои 153 и 48-50 размер очень круто, скрыв недостатки. Классный, тёплый, облегающие по тонкому запястью манжеты, глубокий капюшон, скрадывающий недостатки и подчёркивающий достоинства оверсайзовый фасон (не путать с масс-маркетовскими худаками, от Котово одно название и после стирки они как из *опы). Ткань не мнётся, держит форму.
#
# Заказала ещё два цвета: желтый и серо-кофейный. Желтый очень красивый! Третий цвет пока только жду, но по отзывам и фото девочек он тоже бомбовый!
#
# Ношу на лифчик, а не футболку (зачем?), ничего не линяет, не лезит. Я довольна! Если бы цена на товар не росла в геометрической прогрессии, то купила бы ещё пару цветов точно.
#
# Кофта бомба НОООООО БОЛЬШОЕ НОООО, линяет ворсинками из Нутри! Все в катышках невозможно возврат
# Получила  ,померила все отлично подошло.Цвет совпадает ,размер Овер-вполне подошёл на мой 48 ,рост мой 172 .Надеюсь и после стирки не расстроит .Прекрасное худи👍🏼
# Купила дочери-подростку. Очень качественный, стоит своих денег. Если появятся в другом цвете, закажу ещё!
# Цвет не соответствует. Тусклый. Хотелось бы такой как на фото, яркий и насыщенный. Неужели нельзя сфотографировать в реальном цвете?! В остальном норм. Качество устроило. Теплое, мягкое, приятное к телу. На размеры от 40 до 46 будет очень большим.
# Худи очень, очень оверсайз. Тёплый. Минус звезда, потому что сильно сходит внутренний утеплитель
# Удобный, симпатичный худи
# Отличное худи, очень понравилось, рекомендую
# Худи купила без примерки,  размер и цвет просто любовь с первого взгляда. Постирала,никаких катушек,цвет стал ещё ярче. Я в восторге! Спасибо производителю и магазину за доставку) ощущаю себя как будто в теплом уютном пледике)
# Худи сильно линяет изнутри
# Брала мятный,на мне не понравилось.Кто размера 50 смотрится некрасиво,больше чем на самом деле.Качество хорошее,но лезет конечно, чёрные брюки были в ворсе.
# Не выглядит как оверсайс, а как будто с чужого плеча. Просто большая, а не безразмерная. Короче говоря, не знаю как точнее описать, но ее нужно продавать ни как оверсайс, а просто на нужный размер, например 50-52. Примеряла, решила оставить себе, вдруг что то подойдет под нее, принесла домой, надела с белыми джинсами. Просто кошмар, все белые джинсы в черных катышках и сама толстовка внутри как будто скрутилась, вся внутренняя часть скатывается, и это вторая примерка, что же будет во время носки. Качество очень низкое сильно не соответствует цене, даже в 3 тысячи. Решила вернуть. Ну слишком она низкокачественная. Прошу не снижать процент выкупа.
# На мне не понравилось
# Худи отличного качества,как раз таки правильный оверсайз
# Очень уютная вещичка, мягкая и тёплая, капюшон большой, заменяет шапку)главное-деликатно стирать! Цвет такой же как и на фото)
# Очень качественная вещь, смотрится супер, большая, стильная, очень рекомендую

# %%
#for i in embeddings:
#    for j in clusters[0]:
#        if 
count=0
for i in centroids_embeddings:
    print(i)
    print('*******')
    count+=1
print(count)
# Out:
# [-7.5465236  1.5479171]
# *******
# [ 23.18273  -28.961548]
# *******
# [37.47648 24.07789]
# *******
# 3

# %%
count=0
for i in clusters[0]:
    print(i)
    print('*******')
    count+=1
print(count)
# Out:
# [46.23123   7.505808]
# *******
# [23.225248   5.4044952]
# *******
# [ 24.308975 -36.99471 ]
# *******
# [21.226547  3.351474]
# *******
# [21.762081   6.2822857]
# *******
# [31.881859 24.43531 ]
# *******
# [ 3.808778 25.26431 ]
# *******
# [26.093792  -7.5292797]
# *******
# [11.322559    0.30533183]
# *******
# [45.589466  8.519909]
# *******
# [22.438288  8.027131]
# *******
# [-23.241865   -1.6898085]
# *******
# [30.26724  26.001558]
# *******
# [33.187332 26.65007 ]
# *******
# [26.948431  8.942744]
# *******
# [-8.263897 42.421696]
# *******
# [25.504574  4.407606]
# *******
# [28.704453   3.9657328]
# *******
# [45.8901    6.965314]
# *******
# [47.614403  7.144531]
# *******
# [31.008968 27.800892]
# *******
# [ 22.798656 -16.73651 ]
# *******
# [-14.514789 -17.009745]
# *******
# [-20.668694  -1.700587]
# *******
# [32.662228 26.27693 ]
# *******
# [28.456728   7.4642973]
# *******
# [46.1955     6.1090355]
# *******
# [48.35556    7.2587314]
# *******
# [46.313156   6.0863957]
# *******
# [27.147318  7.391115]
# *******
# [ 15.879003 -41.978745]
# *******
# [18.830627  -3.9011264]
# *******
# [-22.933102   -2.0628448]
# *******
# [27.147655  7.387405]
# *******
# [27.878344   6.5621114]
# *******
# [34.132442 26.80312 ]
# *******
# [-24.444763   -1.8875496]
# *******
# [21.784681  7.890843]
# *******
# [29.082512   3.0223227]
# *******
# [-22.583347   -2.0052218]
# *******
# [47.1773    7.662872]
# *******
# [-29.964855  28.459684]
# *******
# [-22.286987   -2.9281693]
# *******
# [28.887686   3.4511073]
# *******
# [47.614403  7.144531]
# *******
# [19.830982  5.258327]
# *******
# [48.001213  6.781246]
# *******
# [ -1.3157032 -11.903238 ]
# *******
# [-24.03502    -1.8491007]
# *******
# [31.90388  26.156055]
# *******
# [29.324673  8.669972]
# *******
# [ 21.411211 -36.878555]
# *******
# [-24.52796    -1.8592432]
# *******
# [ -4.7228765 -21.592312 ]
# *******
# [27.026638   6.7505946]
# *******
# [25.295021   4.0645366]
# *******
# [31.621845 25.710133]
# *******
# [30.703678 25.18964 ]
# *******
# [23.48324   8.158694]
# *******
# [26.828136  9.081445]
# *******
# [18.917032  4.177341]
# *******
# [26.89121    8.3514595]
# *******
# [18.788065  -4.3578954]
# *******
# [ 22.93621  -18.277906]
# *******
# [27.96525   8.088737]
# *******
# [-14.611415 -19.007736]
# *******
# [15.540973  3.068568]
# *******
# [25.848377  6.957391]
# *******
# [-23.53843    -2.3123767]
# *******
# [33.518677 26.734097]
# *******
# [20.99206   3.890403]
# *******
# [31.831617 25.187506]
# *******
# [-31.485533 -19.313534]
# *******
# [30.785732 23.519337]
# *******
# [31.13527  25.658812]
# *******
# [47.00962   6.609528]
# *******
# [ 24.602787 -36.38917 ]
# *******
# [22.98156   5.325023]
# *******
# [32.622517 25.343536]
# *******
# [34.079777 27.078741]
# *******
# [-22.432817   -1.5389742]
# *******
# [28.257868  8.107   ]
# *******
# [28.737524  8.467166]
# *******
# [45.88997    6.9653087]
# *******
# [ 6.7543736 19.906889 ]
# *******
# [33.326717 26.05652 ]
# *******
# [29.039059  8.522005]
# *******
# [-20.233725   -1.6775644]
# *******
# [31.608738 27.01563 ]
# *******
# 89

# %%
 plt.figure(figsize=(10,10))
for ind, color in zip(clust_indices, colors):
    x = clusters[ind][:,0]
    y = clusters[ind][:,1]
    plt.scatter(x, y, color=color)
    
    centroid = centroids_embeddings[ind]
    plt.scatter(centroid[0],centroid[1], color=color, marker='x', s=100)

plt.show()

# %%
text_link = 'https://www.wildberries.ru/catalog/5044562/detail.aspx?targetUrl=XS'
text_template = r'wildberries\.ru\/catalog\/\d*'
result = re.findall(text_template, text_link)

# %%
final_link=[]
final_link.append(f'https://www.{result[0]}/otzyvy')

# %%
final_link
# Out:
# ['https://www.wildberries.ru/catalog/5044562/otzyvy']

# %%
''.join(final_link)
# Out:
# 'https://www.wildberries.ru/catalog/5044562/otzyvy'

# %%
final_link[0][35:-7]
# Out:
# '5044562'
